# %%
import os
import neptune.new as neptune
import zipfile
import shutil

# === CONFIGURATION ===
API_TOKEN = os.getenv("NEPTUNE_API_TOKEN", "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZjNlODVlNC04NzYwLTQ5ZWItYTUyYy1kY2EwNjBmYjFjODcifQ==")  # Replace with your API token or set the environment variable.
PROJECT_NAME = "sbuser/SX3M"              # Adjust to your project name.
RUN_IDS = {
    "SXM-449": "SXM-449",  # Replace with the actual run identifier if different.
    "SXM-762": "SXM-762"   # Replace with the actual run identifier if different.
}
DOWNLOAD_BASE_DIR = "./neptune_runs"
# Out:
# [neptune] [warning] NeptuneDeprecationWarning: You're importing the Neptune client library via the deprecated `neptune.new` module, which will be removed in a future release. Import directly from `neptune` instead.

# %%
# Create base directory for downloads
os.makedirs(DOWNLOAD_BASE_DIR, exist_ok=True)

# %%
# print(f"Processing run {run_id}...")
# Initialize the run object (read-only mode)
run = neptune.init_run(
    project=PROJECT_NAME,
    api_token=API_TOKEN,
    with="SXM-449",
    mode="read-only"  # Ensure we are not modifying anything.
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # print(f"Processing run {run_id}...")
#       2 # Initialize the run object (read-only mode)
# ----> 3 run = neptune.init_run(
#       4     project=PROJECT_NAME,
#       5     api_token=API_TOKEN,
#       6     run="SXM-449",
#       7     mode="read-only"  # Ensure we are not modifying anything.
#       8 )
#
# File /app/.venv/lib/python3.12/site-packages/neptune/metadata_containers/run.py:335, in Run.__init__(self, with_id, project, api_token, custom_run_id, mode, name, description, tags, source_files, capture_stdout, capture_stderr, capture_hardware_metrics, fail_on_exception, monitoring_namespace, flush_period, proxies, capture_traceback, git_ref, dependencies, async_lag_callback, async_lag_threshold, async_no_progress_callback, async_no_progress_threshold, **kwargs)
#     307 def __init__(
#     308     self,
#     309     with_id: Optional[str] = None,
#    (...)    333     **kwargs,
#     334 ):
# --> 335     check_for_extra_kwargs("Run", kwargs)
#     337     verify_type("with_id", with_id, (str, type(None)))
#     338     verify_type("project", project, (str, type(None)))
#
# File /app/.venv/lib/python3.12/site-packages/neptune/metadata_containers/run.py:593, in check_for_extra_kwargs(caller_name, kwargs)
#     591 if kwargs:
#     592     first_key = next(iter(kwargs.keys()))
# --> 593     raise TypeError(f"{caller_name}() got an unexpected keyword argument '{first_key}'")
#
# TypeError: Run() got an unexpected keyword argument 'run'

# %%
p =neptune.Project(project="sbuser/SX3M",
                  api_token=os.getenv("NEPTUNE_API_TOKEN", "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZjNlODVlNC04NzYwLTQ5ZWItYTUyYy1kY2EwNjBmYjFjODcifQ==")  )
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/sbuser/SX3M/

# %%
p.fetch_models_table().to_pandas()
# Out:
#         sys/creation_time    sys/id   sys/modification_time  \
# 0 2023-11-15 18:12:51.191  SXM-LGBM 2023-11-15 18:12:51.777
# 1 2023-11-15 18:12:38.517  SXM-XGRF 2023-11-15 18:12:38.936
# 2 2023-11-15 18:12:25.699    SXM-XG 2023-11-15 18:12:26.138
# 3 2023-11-15 18:12:17.262    SXM-RF 2023-11-15 18:12:17.690
# 4 2023-11-15 18:12:09.287    SXM-LR 2023-11-15 18:12:09.715
# 5 2023-11-15 18:12:03.667   SXM-DUM 2023-11-15 18:12:04.222
#
#    sys/monitoring_time  sys/name sys/owner           sys/ping_time  \
# 0                    0  Untitled    sbuser 2023-11-15 18:15:24.298
# 1                    0  Untitled    sbuser 2023-11-15 18:15:21.761
# 2                    0  Untitled    sbuser 2023-11-15 18:15:29.314
# 3                    0  Untitled    sbuser 2023-11-15 18:15:21.104
# 4                    0  Untitled    sbuser 2023-11-15 18:15:23.136
# 5                    0  Untitled    sbuser 2023-11-15 18:15:27.692
#
#    sys/running_time  sys/size sys/state sys/tags  sys/trashed
# 0           132.937      28.0  Inactive                 False
# 1           163.238      28.0  Inactive                 False
# 2           183.605      28.0  Inactive                 False
# 3           183.832      28.0  Inactive                 False
# 4           193.841      28.0  Inactive                 False
# 5           204.013      28.0  Inactive                 False

# %%
model = neptune.Model(project="sbuser/SX3M", mode="read-only", with_id="SXM-XGRF",
                  api_token=os.getenv("NEPTUNE_API_TOKEN", "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZjNlODVlNC04NzYwLTQ5ZWItYTUyYy1kY2EwNjBmYjFjODcifQ==")  )
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/sbuser/SX3M/m/SXM-XGRF

# %%
model.fetch_model_versions_table().to_pandas().T
# Out:
#                                                                                   0  \
# sys/creation_time                                        2023-11-16 04:13:47.948000
# sys/id                                                                   SXM-XGRF-5
# sys/model_id                                                               SXM-XGRF
# sys/modification_time                                    2023-11-16 04:13:48.362000
# sys/monitoring_time                                                               1
# sys/owner                                                                    sbuser
# sys/ping_time                                            2023-11-16 11:10:41.305000
# sys/running_time                                                           25012.12
# sys/size                                                                     1777.0
# sys/stage                                                                      none
# sys/state                                                                  Inactive
# sys/tags
# sys/trashed                                                                   False
# estimator/class                           <class 'xgboost.sklearn.XGBRFClassifier'>
# estimator/params/base_score                                                    None
# estimator/params/booster                                                     gbtree
# estimator/params/callbacks                                                     None
# estimator/params/colsample_bylevel                                             None
# estimator/params/colsample_bynode                                               0.8
# estimator/params/colsample_bytree                                               1.0
# estimator/params/device                                                        None
# estimator/params/early_stopping_rounds                                         None
# estimator/params/enable_categorical                                            True
# estimator/params/eval_metric                                              error@0.7
# estimator/params/feature_types                                                 None
# estimator/params/gamma                                                          0.2
# estimator/params/grow_policy                                                   None
# estimator/params/importance_type                                               None
# estimator/params/interaction_constraints                                       None
# estimator/params/learning_rate                                                  0.1
# estimator/params/max_bin                                                       None
# estimator/params/max_cat_threshold                                             None
# estimator/params/max_cat_to_onehot                                             None
# estimator/params/max_delta_step                                                None
# estimator/params/max_depth                                                        4
# estimator/params/max_leaves                                                    None
# estimator/params/min_child_weight                                                10
# estimator/params/monotone_constraints                                          None
# estimator/params/multi_strategy                                                None
# estimator/params/n_estimators                                                   500
# estimator/params/n_jobs                                                          -1
# estimator/params/num_parallel_tree                                              100
# estimator/params/objective                                          binary:logistic
# estimator/params/random_state                                                   183
# estimator/params/reg_alpha                                                      0.2
# estimator/params/reg_lambda                                                       2
# estimator/params/sampling_method                                               None
# estimator/params/scale_pos_weight                                              None
# estimator/params/subsample                                                      0.8
# estimator/params/tree_method                                                   None
# estimator/params/validate_parameters                                           None
# estimator/params/verbosity                                                        0
#
#                                                                                   1  \
# sys/creation_time                                        2023-11-15 21:25:27.185000
# sys/id                                                                   SXM-XGRF-4
# sys/model_id                                                               SXM-XGRF
# sys/modification_time                                    2023-11-15 21:25:28.178000
# sys/monitoring_time                                                               1
# sys/owner                                                                    sbuser
# sys/ping_time                                            2023-11-16 02:17:59.819000
# sys/running_time                                                          17531.571
# sys/size                                                                     1777.0
# sys/stage                                                                      none
# sys/state                                                                  Inactive
# sys/tags
# sys/trashed                                                                   False
# estimator/class                           <class 'xgboost.sklearn.XGBRFClassifier'>
# estimator/params/base_score                                                    None
# estimator/params/booster                                                     gbtree
# estimator/params/callbacks                                                     None
# estimator/params/colsample_bylevel                                             None
# estimator/params/colsample_bynode                                               0.8
# estimator/params/colsample_bytree                                               1.0
# estimator/params/device                                                        None
# estimator/params/early_stopping_rounds                                         None
# estimator/params/enable_categorical                                            True
# estimator/params/eval_metric                                              error@0.7
# estimator/params/feature_types                                                 None
# estimator/params/gamma                                                          0.2
# estimator/params/grow_policy                                                   None
# estimator/params/importance_type                                               None
# estimator/params/interaction_constraints                                       None
# estimator/params/learning_rate                                                  0.1
# estimator/params/max_bin                                                       None
# estimator/params/max_cat_threshold                                             None
# estimator/params/max_cat_to_onehot                                             None
# estimator/params/max_delta_step                                                None
# estimator/params/max_depth                                                        4
# estimator/params/max_leaves                                                    None
# estimator/params/min_child_weight                                                10
# estimator/params/monotone_constraints                                          None
# estimator/params/multi_strategy                                                None
# estimator/params/n_estimators                                                   500
# estimator/params/n_jobs                                                          -1
# estimator/params/num_parallel_tree                                              100
# estimator/params/objective                                          binary:logistic
# estimator/params/random_state                                                   518
# estimator/params/reg_alpha                                                      0.2
# estimator/params/reg_lambda                                                       2
# estimator/params/sampling_method                                               None
# estimator/params/scale_pos_weight                                              None
# estimator/params/subsample                                                      0.8
# estimator/params/tree_method                                                   None
# estimator/params/validate_parameters                                           None
# estimator/params/verbosity                                                        0
#
#                                                                                   2  \
# sys/creation_time                                        2023-11-15 20:56:44.850000
# sys/id                                                                   SXM-XGRF-3
# sys/model_id                                                               SXM-XGRF
# sys/modification_time                                    2023-11-15 20:56:45.646000
# sys/monitoring_time                                                               1
# sys/owner                                                                    sbuser
# sys/ping_time                                            2023-11-15 20:57:05.811000
# sys/running_time                                                              0.796
# sys/size                                                                     1784.0
# sys/stage                                                                      none
# sys/state                                                                  Inactive
# sys/tags
# sys/trashed                                                                   False
# estimator/class                           <class 'xgboost.sklearn.XGBRFClassifier'>
# estimator/params/base_score                                                    None
# estimator/params/booster                                                     gbtree
# estimator/params/callbacks                                                     None
# estimator/params/colsample_bylevel                                             None
# estimator/params/colsample_bynode                                               0.8
# estimator/params/colsample_bytree                                               1.0
# estimator/params/device                                                        None
# estimator/params/early_stopping_rounds                                         None
# estimator/params/enable_categorical                                            True
# estimator/params/eval_metric                                              error@0.7
# estimator/params/feature_types                                                 None
# estimator/params/gamma                                                          0.2
# estimator/params/grow_policy                                                   None
# estimator/params/importance_type                                               None
# estimator/params/interaction_constraints                                       None
# estimator/params/learning_rate                                                  0.1
# estimator/params/max_bin                                                       None
# estimator/params/max_cat_threshold                                             None
# estimator/params/max_cat_to_onehot                                             None
# estimator/params/max_delta_step                                                None
# estimator/params/max_depth                                                        4
# estimator/params/max_leaves                                                    None
# estimator/params/min_child_weight                                                10
# estimator/params/monotone_constraints                                          None
# estimator/params/multi_strategy                                                None
# estimator/params/n_estimators                                                   500
# estimator/params/n_jobs                                                          -1
# estimator/params/num_parallel_tree                                              100
# estimator/params/objective                                          binary:logistic
# estimator/params/random_state                                            1802359851
# estimator/params/reg_alpha                                                      0.2
# estimator/params/reg_lambda                                                       2
# estimator/params/sampling_method                                               None
# estimator/params/scale_pos_weight                                              None
# estimator/params/subsample                                                      0.8
# estimator/params/tree_method                                                   None
# estimator/params/validate_parameters                                           None
# estimator/params/verbosity                                                        0
#
#                                                                                   3  \
# sys/creation_time                                        2023-11-15 18:35:16.079000
# sys/id                                                                   SXM-XGRF-2
# sys/model_id                                                               SXM-XGRF
# sys/modification_time                                    2023-11-15 18:35:16.778000
# sys/monitoring_time                                                               1
# sys/owner                                                                    sbuser
# sys/ping_time                                            2023-11-16 14:15:41.852000
# sys/running_time                                                          31811.918
# sys/size                                                                     1776.0
# sys/stage                                                                      none
# sys/state                                                                  Inactive
# sys/tags
# sys/trashed                                                                   False
# estimator/class                           <class 'xgboost.sklearn.XGBRFClassifier'>
# estimator/params/base_score                                                    None
# estimator/params/booster                                                     gbtree
# estimator/params/callbacks                                                     None
# estimator/params/colsample_bylevel                                             None
# estimator/params/colsample_bynode                                               0.8
# estimator/params/colsample_bytree                                               1.0
# estimator/params/device                                                        None
# estimator/params/early_stopping_rounds                                         None
# estimator/params/enable_categorical                                            True
# estimator/params/eval_metric                                              error@0.7
# estimator/params/feature_types                                                 None
# estimator/params/gamma                                                          0.2
# estimator/params/grow_policy                                                   None
# estimator/params/importance_type                                               None
# estimator/params/interaction_constraints                                       None
# estimator/params/learning_rate                                                  0.1
# estimator/params/max_bin                                                       None
# estimator/params/max_cat_threshold                                             None
# estimator/params/max_cat_to_onehot                                             None
# estimator/params/max_delta_step                                                None
# estimator/params/max_depth                                                        4
# estimator/params/max_leaves                                                    None
# estimator/params/min_child_weight                                                10
# estimator/params/monotone_constraints                                          None
# estimator/params/multi_strategy                                                None
# estimator/params/n_estimators                                                   500
# estimator/params/n_jobs                                                          -1
# estimator/params/num_parallel_tree                                              100
# estimator/params/objective                                          binary:logistic
# estimator/params/random_state                                                    42
# estimator/params/reg_alpha                                                      0.2
# estimator/params/reg_lambda                                                       2
# estimator/params/sampling_method                                               None
# estimator/params/scale_pos_weight                                              None
# estimator/params/subsample                                                      0.8
# estimator/params/tree_method                                                   None
# estimator/params/validate_parameters                                           None
# estimator/params/verbosity                                                        0
#
#                                                                                   4
# sys/creation_time                                        2023-11-15 18:12:39.457000
# sys/id                                                                   SXM-XGRF-1
# sys/model_id                                                               SXM-XGRF
# sys/modification_time                                    2023-11-15 18:12:40.198000
# sys/monitoring_time                                                               1
# sys/owner                                                                    sbuser
# sys/ping_time                                            2023-11-15 18:15:22.947000
# sys/running_time                                                            163.482
# sys/size                                                                     1776.0
# sys/stage                                                                      none
# sys/state                                                                  Inactive
# sys/tags
# sys/trashed                                                                   False
# estimator/class                           <class 'xgboost.sklearn.XGBRFClassifier'>
# estimator/params/base_score                                                    None
# estimator/params/booster                                                     gbtree
# estimator/params/callbacks                                                     None
# estimator/params/colsample_bylevel                                             None
# estimator/params/colsample_bynode                                               0.8
# estimator/params/colsample_bytree                                               1.0
# estimator/params/device                                                        None
# estimator/params/early_stopping_rounds                                         None
# estimator/params/enable_categorical                                            True
# estimator/params/eval_metric                                              error@0.7
# estimator/params/feature_types                                                 None
# estimator/params/gamma                                                          0.2
# estimator/params/grow_policy                                                   None
# estimator/params/importance_type                                               None
# estimator/params/interaction_constraints                                       None
# estimator/params/learning_rate                                                  0.1
# estimator/params/max_bin                                                       None
# estimator/params/max_cat_threshold                                             None
# estimator/params/max_cat_to_onehot                                             None
# estimator/params/max_delta_step                                                None
# estimator/params/max_depth                                                        4
# estimator/params/max_leaves                                                    None
# estimator/params/min_child_weight                                                10
# estimator/params/monotone_constraints                                          None
# estimator/params/multi_strategy                                                None
# estimator/params/n_estimators                                                   500
# estimator/params/n_jobs                                                          -1
# estimator/params/num_parallel_tree                                              100
# estimator/params/objective                                          binary:logistic
# estimator/params/random_state                                                    42
# estimator/params/reg_alpha                                                      0.2
# estimator/params/reg_lambda                                                       2
# estimator/params/sampling_method                                               None
# estimator/params/scale_pos_weight                                              None
# estimator/params/subsample                                                      0.8
# estimator/params/tree_method                                                   None
# estimator/params/validate_parameters                                           None
# estimator/params/verbosity                                                        0

# %%
run = neptune.Run(project="sbuser/SX3M", mode="read-only", with_id="SXM-449",
                  api_token=os.getenv("NEPTUNE_API_TOKEN", "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZjNlODVlNC04NzYwLTQ5ZWItYTUyYy1kY2EwNjBmYjFjODcifQ==")  )
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/sbuser/SX3M/e/SXM-449

# %%
mrun = run.fetch()['model']

# %%
run_structure = run.print_structure()
# Out:
# 'hyperparameters_set_pct_size': Integer
# 'model':
#     'Dummy':
#         'estimator':
#             'class': String
#             'params':
#                 'constant': String
#                 'random_state': String
#                 'strategy': String
#         'sys':
#             'creation_time': Datetime
#             'id': String
#             'model_id': String
#             'modification_time': Datetime
#             'monitoring_time': Integer
#             'owner': String
#             'ping_time': Datetime
#             'running_time': Float
#             'size': Float
#             'stage': String
#             'state': String
#             'trashed': Boolean
#     'LightGBM':
#         'estimator':
#             'class': String
#             'params':
#                 'bagging_fraction': Float
#                 'bagging_freq': Integer
#                 'boosting_type': String
#                 'class_weight': String
#                 'colsample_bytree': Float
#                 'deterministic': Boolean
#                 'feature_fraction': Float
#                 'force_col_wise': Boolean
#                 'importance_type': String
#                 'lambda_l1': Integer
#                 'lambda_l2': Integer
#                 'learning_rate': Float
#                 'max_depth': Integer
#                 'min_child_samples': Integer
#                 'min_child_weight': Float
#                 'min_gain_to_split': Float
#                 'min_split_gain': Float
#                 'n_estimators': Integer
#                 'n_jobs': Integer
#                 'num_leaves': Integer
#                 'objective': String
#                 'random_state': String
#                 'reg_alpha': Float
#                 'reg_lambda': Float
#                 'subsample': Float
#                 'subsample_for_bin': Integer
#                 'subsample_freq': Integer
#                 'verbose': Integer
#         'hyperoptimized_best_params':
#             'bagging_fraction': Float
#             'bagging_freq': Integer
#             'extra_trees': Boolean
#             'feature_fraction': Float
#             'lambda_l1': Integer
#             'lambda_l2': Integer
#             'learning_rate': Float
#             'max_depth': Integer
#             'min_data_in_leaf': Integer
#             'min_gain_to_split': Float
#             'min_sum_hessian_in_leaf': Integer
#             'n_estimators': Integer
#             'num_leaves': Integer
#             'objective': String
#             'train_size': Integer
#         'sys':
#             'creation_time': Datetime
#             'id': String
#             'model_id': String
#             'modification_time': Datetime
#             'monitoring_time': Integer
#             'owner': String
#             'ping_time': Datetime
#             'running_time': Float
#             'size': Float
#             'stage': String
#             'state': String
#             'trashed': Boolean
#         'tuning':
#             'best':
#                 'params':
#                     'bagging_fraction': Float
#                     'bagging_freq': Integer
#                     'extra_trees': Boolean
#                     'feature_fraction': Float
#                     'lambda_l1': Integer
#                     'lambda_l2': Integer
#                     'learning_rate': Float
#                     'max_depth': Integer
#                     'min_data_in_leaf': Integer
#                     'min_gain_to_split': Float
#                     'min_sum_hessian_in_leaf': Float
#                     'n_estimators': Integer
#                     'num_leaves': Integer
#                     'objective': String
#                     'train_size': Integer
#                 'trials':
#                     '0':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '10':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '49':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '5':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Integer
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '9':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                 'value': Float
#                 'value|params': String
#             'study':
#                 '_storage': String
#                 '_study_id': Integer
#                 'direction': Integer
#                 'distributions':
#                     'bagging_fraction': String
#                     'bagging_freq': String
#                     'extra_trees': String
#                     'feature_fraction': String
#                     'lambda_l1': String
#                     'lambda_l2': String
#                     'learning_rate': String
#                     'max_depth': String
#                     'min_data_in_leaf': String
#                     'min_gain_to_split': String
#                     'min_sum_hessian_in_leaf': String
#                     'n_estimators': String
#                     'num_leaves': String
#                     'objective': String
#                     'train_size': String
#                 'storage_type': String
#                 'study': File
#                 'study_name': String
#             'trials':
#                 'params':
#                     'bagging_fraction': FloatSeries
#                     'bagging_freq': FloatSeries
#                     'extra_trees': FloatSeries
#                     'feature_fraction': FloatSeries
#                     'lambda_l1': FloatSeries
#                     'lambda_l2': FloatSeries
#                     'learning_rate': FloatSeries
#                     'max_depth': FloatSeries
#                     'min_data_in_leaf': FloatSeries
#                     'min_gain_to_split': FloatSeries
#                     'min_sum_hessian_in_leaf': FloatSeries
#                     'n_estimators': FloatSeries
#                     'num_leaves': FloatSeries
#                     'objective': StringSeries
#                     'train_size': FloatSeries
#                 'trials':
#                     '0':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '1':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Float
#                             'lambda_l2': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '10':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '11':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '12':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '13':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '14':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '15':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '16':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '17':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '18':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '19':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '2':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '20':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '21':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '22':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '23':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '24':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '25':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
# ...
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '45':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '46':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '47':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '48':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '49':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '5':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '6':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '7':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '8':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '9':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                 'values': FloatSeries
#                 'values|params': StringSeries
#             'visualizations':
#                 'plot_contour': File
#                 'plot_edf': File
#                 'plot_optimization_history': File
#                 'plot_parallel_coordinate': File
#                 'plot_param_importances': File
#                 'plot_slice': File
# 'monitoring':
#     '8c08bc31':
#         'cpu': FloatSeries
#         'hostname': String
#         'memory': FloatSeries
#         'pid': String
#         'stderr': StringSeries
#         'stdout': StringSeries
#         'tid': String
# 'ndays_hyperparameter_set': Integer
# 'ndays_validation_set': Integer
# 'source_code':
#     'entrypoint': String
#     'integrations':
#         'neptune-optuna': String
# 'sys':
#     'creation_time': Datetime
#     'description': String
#     'failed': Boolean
#     'group_tags': StringSet
#     'hostname': String
#     'id': String
#     'modification_time': Datetime
#     'monitoring_time': Integer
#     'name': String
#     'owner': String
#     'ping_time': Datetime
#     'running_time': Float
#     'size': Float
#     'state': RunState
#     'tags': StringSet
#     'trashed': Boolean

# %%
ns=run["model"]

# %%
ns.container.print_structure()
for i in ns["model"]:
    i.fetch()
# Out:
# 'hyperparameters_set_pct_size': Integer
# 'model':
#     'Dummy':
#         'estimator':
#             'class': String
#             'params':
#                 'constant': String
#                 'random_state': String
#                 'strategy': String
#         'sys':
#             'creation_time': Datetime
#             'id': String
#             'model_id': String
#             'modification_time': Datetime
#             'monitoring_time': Integer
#             'owner': String
#             'ping_time': Datetime
#             'running_time': Float
#             'size': Float
#             'stage': String
#             'state': String
#             'trashed': Boolean
#     'LightGBM':
#         'estimator':
#             'class': String
#             'params':
#                 'bagging_fraction': Float
#                 'bagging_freq': Integer
#                 'boosting_type': String
#                 'class_weight': String
#                 'colsample_bytree': Float
#                 'deterministic': Boolean
#                 'feature_fraction': Float
#                 'force_col_wise': Boolean
#                 'importance_type': String
#                 'lambda_l1': Integer
#                 'lambda_l2': Integer
#                 'learning_rate': Float
#                 'max_depth': Integer
#                 'min_child_samples': Integer
#                 'min_child_weight': Float
#                 'min_gain_to_split': Float
#                 'min_split_gain': Float
#                 'n_estimators': Integer
#                 'n_jobs': Integer
#                 'num_leaves': Integer
#                 'objective': String
#                 'random_state': String
#                 'reg_alpha': Float
#                 'reg_lambda': Float
#                 'subsample': Float
#                 'subsample_for_bin': Integer
#                 'subsample_freq': Integer
#                 'verbose': Integer
#         'hyperoptimized_best_params':
#             'bagging_fraction': Float
#             'bagging_freq': Integer
#             'extra_trees': Boolean
#             'feature_fraction': Float
#             'lambda_l1': Integer
#             'lambda_l2': Integer
#             'learning_rate': Float
#             'max_depth': Integer
#             'min_data_in_leaf': Integer
#             'min_gain_to_split': Float
#             'min_sum_hessian_in_leaf': Integer
#             'n_estimators': Integer
#             'num_leaves': Integer
#             'objective': String
#             'train_size': Integer
#         'sys':
#             'creation_time': Datetime
#             'id': String
#             'model_id': String
#             'modification_time': Datetime
#             'monitoring_time': Integer
#             'owner': String
#             'ping_time': Datetime
#             'running_time': Float
#             'size': Float
#             'stage': String
#             'state': String
#             'trashed': Boolean
#         'tuning':
#             'best':
#                 'params':
#                     'bagging_fraction': Float
#                     'bagging_freq': Integer
#                     'extra_trees': Boolean
#                     'feature_fraction': Float
#                     'lambda_l1': Integer
#                     'lambda_l2': Integer
#                     'learning_rate': Float
#                     'max_depth': Integer
#                     'min_data_in_leaf': Integer
#                     'min_gain_to_split': Float
#                     'min_sum_hessian_in_leaf': Float
#                     'n_estimators': Integer
#                     'num_leaves': Integer
#                     'objective': String
#                     'train_size': Integer
#                 'trials':
#                     '0':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '10':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '49':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '5':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Integer
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '9':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                 'value': Float
#                 'value|params': String
#             'study':
#                 '_storage': String
#                 '_study_id': Integer
#                 'direction': Integer
#                 'distributions':
#                     'bagging_fraction': String
#                     'bagging_freq': String
#                     'extra_trees': String
#                     'feature_fraction': String
#                     'lambda_l1': String
#                     'lambda_l2': String
#                     'learning_rate': String
#                     'max_depth': String
#                     'min_data_in_leaf': String
#                     'min_gain_to_split': String
#                     'min_sum_hessian_in_leaf': String
#                     'n_estimators': String
#                     'num_leaves': String
#                     'objective': String
#                     'train_size': String
#                 'storage_type': String
#                 'study': File
#                 'study_name': String
#             'trials':
#                 'params':
#                     'bagging_fraction': FloatSeries
#                     'bagging_freq': FloatSeries
#                     'extra_trees': FloatSeries
#                     'feature_fraction': FloatSeries
#                     'lambda_l1': FloatSeries
#                     'lambda_l2': FloatSeries
#                     'learning_rate': FloatSeries
#                     'max_depth': FloatSeries
#                     'min_data_in_leaf': FloatSeries
#                     'min_gain_to_split': FloatSeries
#                     'min_sum_hessian_in_leaf': FloatSeries
#                     'n_estimators': FloatSeries
#                     'num_leaves': FloatSeries
#                     'objective': StringSeries
#                     'train_size': FloatSeries
#                 'trials':
#                     '0':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '1':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Float
#                             'lambda_l2': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '10':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '11':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '12':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '13':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '14':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '15':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '16':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '17':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '18':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '19':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '2':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Float
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '20':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '21':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '22':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '23':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '24':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'bagging_fraction': String
#                             'bagging_freq': String
#                             'extra_trees': String
#                             'feature_fraction': String
#                             'lambda_l1': String
#                             'lambda_l2': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_data_in_leaf': String
#                             'min_gain_to_split': String
#                             'min_sum_hessian_in_leaf': String
#                             'n_estimators': String
#                             'num_leaves': String
#                             'objective': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'bagging_fraction': Float
#                             'bagging_freq': Integer
#                             'extra_trees': Boolean
#                             'feature_fraction': Float
#                             'lambda_l1': Integer
#                             'lambda_l2': Integer
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_data_in_leaf': Integer
#                             'min_gain_to_split': Float
#                             'min_sum_hessian_in_leaf': Integer
#                             'n_estimators': Integer
#                             'num_leaves': Integer
#                             'objective': String
#                             'train_size': Integer
#                         'value': Float
#                     '25':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
# ...
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '46':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '47':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '48':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '49':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '5':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '6':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '7':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '8':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                     '9':
#                         'datetime_complete': Datetime
#                         'datetime_start': Datetime
#                         'distributions':
#                             'colsample_bytree': String
#                             'eval_metric': String
#                             'gamma': String
#                             'learning_rate': String
#                             'max_depth': String
#                             'min_child_weight': String
#                             'n_estimators': String
#                             'reg_alpha': String
#                             'reg_lambda': String
#                             'subsample': String
#                             'train_size': String
#                         'duration': String
#                         'params':
#                             'colsample_bytree': Float
#                             'eval_metric': String
#                             'gamma': Float
#                             'learning_rate': Float
#                             'max_depth': Integer
#                             'min_child_weight': Integer
#                             'n_estimators': Integer
#                             'reg_alpha': Float
#                             'reg_lambda': Integer
#                             'subsample': Float
#                             'train_size': Integer
#                         'value': Float
#                 'values': FloatSeries
#                 'values|params': StringSeries
#             'visualizations':
#                 'plot_contour': File
#                 'plot_edf': File
#                 'plot_optimization_history': File
#                 'plot_parallel_coordinate': File
#                 'plot_param_importances': File
#                 'plot_slice': File
# 'monitoring':
#     '8c08bc31':
#         'cpu': FloatSeries
#         'hostname': String
#         'memory': FloatSeries
#         'pid': String
#         'stderr': StringSeries
#         'stdout': StringSeries
#         'tid': String
# 'ndays_hyperparameter_set': Integer
# 'ndays_validation_set': Integer
# 'source_code':
#     'entrypoint': String
#     'integrations':
#         'neptune-optuna': String
# 'sys':
#     'creation_time': Datetime
#     'description': String
#     'failed': Boolean
#     'group_tags': StringSet
#     'hostname': String
#     'id': String
#     'modification_time': Datetime
#     'monitoring_time': Integer
#     'name': String
#     'owner': String
#     'ping_time': Datetime
#     'running_time': Float
#     'size': Float
#     'state': RunState
#     'tags': StringSet
#     'trashed': Boolean
# ---------------------------------------------------------------------------
# MissingFieldException                     Traceback (most recent call last)
# Cell In[63], line 3
#       1 ns.container.print_structure()
#       2 for i in ns["model"]:
# ----> 3     i.fetch()
#
# File /app/.venv/lib/python3.12/site-packages/neptune/handler.py:567, in Handler.fetch(self)
#     547 def fetch(self):
#     548     """Fetches fields value or, in case of a namespace, fetches values of all non-File Atom fields as a dictionary.
#     549
#     550     Available for the following field types:
#    (...)    565        https://docs.neptune.ai/api-reference/field-types
#     566     """
# --> 567     return self._pass_call_to_attr(function_name="fetch")
#
# File /app/.venv/lib/python3.12/site-packages/neptune/handler.py:748, in Handler._pass_call_to_attr(self, function_name, **kwargs)
#     747 def _pass_call_to_attr(self, function_name, **kwargs):
# --> 748     return getattr(self._get_attribute(), function_name)(**kwargs)
#
# File /app/.venv/lib/python3.12/site-packages/neptune/handler.py:150, in Handler._get_attribute(self)
#     148 attr = self._container.get_attribute(self._path)
#     149 if attr is None:
# --> 150     raise MissingFieldException(self._path)
#     151 return attr
#
# MissingFieldException:
#
# ----MissingFieldException-------------------------------------------------------
#
# The field "model/model/0" was not found.
#
# There are two possible reasons:
#     - There is a typo in the path. Double-check your code for typos.
#     - You are fetching a field that another process created, but the local representation is not synchronized.
#     If you are sending metadata from multiple processes at the same time, synchronize the local representation before fetching values:
#         run.sync()
#
# Need help?-> https://docs.neptune.ai/getting_help

# %%
def download_run_data(run_id):
    print(f"Processing run {run_id}...")
    # Initialize the run object (read-only mode)
    run = neptune.init_run(
        project=PROJECT_NAME,
        api_token=API_TOKEN,
        run=run_id,
        mode="read-only"  # Ensure we are not modifying anything.
    )
    
    # Create a subdirectory for this run
    run_dir = os.path.join(DOWNLOAD_BASE_DIR, run_id)
    os.makedirs(run_dir, exist_ok=True)

    # Download all files (artifacts & metadata)
    # Note: You might need to adjust the download_files call according to your Neptune version
    run.download_files(destination=run_dir)
    
    # Terminate the run to free resources
    run.stop()
    
    # Zip the downloaded directory
    zip_filename = os.path.join(DOWNLOAD_BASE_DIR, f"{run_id}_run_data.zip")
    print(f"Creating ZIP file: {zip_filename}")
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(run_dir):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, run_dir))
    
    # Optionally, remove the unzipped files to save space
    shutil.rmtree(run_dir)
    print(f"Run {run_id} data has been downloaded and zipped.\n")

for run_label, run_id in RUN_IDS.items():
    download_run_data(run_id)
